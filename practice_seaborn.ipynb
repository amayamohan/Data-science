# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = sns.load_dataset('tips')
sns.histplot(df['total_bill'], bins=30,kde=True, color='blue')
plt.title("Total Bill Distribution")
plt.show()

# %%
data = pd.DataFrame({"category": ['A', 'B', 'C', 'D'],
                     "values": [4,7,2,9]})

sns.barplot(x='category', y='values', data=data)
plt.title("Bar Plot using Seaborn")
plt.show()

# %%
sns.countplot(x='day', data=df, palette='Set2')
plt.title("Count Plot of Days")
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8816\1678498382.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='day', data=df, palette='Set2')

# %%
sns.boxplot(x='day', y='total_bill', data=df, palette='pastel')
plt.title("Box Plot")
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8816\806922173.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y='total_bill', data=df, palette='pastel')

# %%
sns.scatterplot(x='total_bill', y='tip', data = df, hue='sex',style = "time")
plt.title("Scatter Plot")
plt.show()
