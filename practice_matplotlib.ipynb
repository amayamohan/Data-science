# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y, color= 'red', linestyle= '--', marker= '+')
plt.title("Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
